# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Loan_default.csv')
df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
df = df.drop(columns= ['LoanID','LoanPurpose','HasCoSigner'])

# %%
df
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0        56   85994       50587          520              80               4
# 1        69   50432      124440          458              15               1
# 2        46   84208      129188          451              26               3
# 3        32   31713       44799          743               0               3
# 4        60   20437        9139          633               8               4
# ...     ...     ...         ...          ...             ...             ...
# 255342   19   37979      210682          541             109               4
# 255343   32   51953      189899          511              14               2
# 255344   56   84820      208294          597              70               3
# 255345   42   85109       60575          809              40               1
# 255346   62   22418       18481          636             113               2
#
# ...

# %%
df['Education'] = df['Education'].astype('category')
df['Education'] = df['Education'].cat.codes
df
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0        56   85994       50587          520              80               4
# 1        69   50432      124440          458              15               1
# 2        46   84208      129188          451              26               3
# 3        32   31713       44799          743               0               3
# 4        60   20437        9139          633               8               4
# ...     ...     ...         ...          ...             ...             ...
# 255342   19   37979      210682          541             109               4
# 255343   32   51953      189899          511              14               2
# 255344   56   84820      208294          597              70               3
# 255345   42   85109       60575          809              40               1
# 255346   62   22418       18481          636             113               2
#
# ...

# %%
df['EmploymentType'] = df['EmploymentType'].astype('category')
df['EmploymentType'] = df['EmploymentType'].cat.codes

df['MaritalStatus'] = df['MaritalStatus'].astype('category')
df['MaritalStatus'] = df['MaritalStatus'].cat.codes

df['HasMortgage'] = df['HasMortgage'].astype('category')
df['HasMortgage'] = df['HasMortgage'].cat.codes

df['HasDependents'] = df['HasDependents'].astype('category')
df['HasDependents'] = df['HasDependents'].cat.codes

df
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0        56   85994       50587          520              80               4
# 1        69   50432      124440          458              15               1
# 2        46   84208      129188          451              26               3
# 3        32   31713       44799          743               0               3
# 4        60   20437        9139          633               8               4
# ...     ...     ...         ...          ...             ...             ...
# 255342   19   37979      210682          541             109               4
# 255343   32   51953      189899          511              14               2
# 255344   56   84820      208294          597              70               3
# 255345   42   85109       60575          809              40               1
# 255346   62   22418       18481          636             113               2
#
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# Default           0
# dtype: int64

# %%
X = df.drop(columns='Default')

# %%
X
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0        56   85994       50587          520              80               4
# 1        69   50432      124440          458              15               1
# 2        46   84208      129188          451              26               3
# 3        32   31713       44799          743               0               3
# 4        60   20437        9139          633               8               4
# ...     ...     ...         ...          ...             ...             ...
# 255342   19   37979      210682          541             109               4
# 255343   32   51953      189899          511              14               2
# 255344   56   84820      208294          597              70               3
# 255345   42   85109       60575          809              40               1
# 255346   62   22418       18481          636             113               2
#
# ...

# %%
Y = df['Default']

# %%
Y
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 255342    0
# 255343    1
# 255344    0
# 255345    0
# 255346    0
# Name: Default, Length: 255347, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test =  train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 120619   63   15059       70015          739              87               3
# 86171    54  113722      162395          805              22               3
# 10433    37   63953       19166          637              56               1
# 121331   24   75686       27350          547              24               3
# 14129    45   24160      144568          446              73               2
# ...     ...     ...         ...          ...             ...             ...
# 119879   40  116623      161673          651              79               2
# 103694   67   62958      189499          460              77               3
# 131932   62   34372       59645          524              94               3
# 146867   44  146262      198454          489               7               4
# 121958   36   97844      188593          542               2               3
#
# ...

# %%
X_test
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 51139    55  112656       92393          581             113               2
# 71005    56   91569      131575          641              54               1
# 35684    26   78169       75417          569             105               3
# 174087   26   63033       10804          326             118               1
# 137952   24   29665       21182          662             102               3
# ...     ...     ...         ...          ...             ...             ...
# 148888   39   88128       29812          421              42               1
# 123352   66  141722       65241          493              53               1
# 139514   37   31113      135440          342               2               3
# 21478    60   48956       33712          559               7               3
# 101108   40  105611      143384          457              84               3
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train) 
#fit transform stores and uses the mean and SD for fitting of the model

# %%
X_test_scaled = scaler.transform(X_test) 
#transform does not stores the mean and SD because we do not need the assumptions from the test datset

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(random_state=0).fit(X_train_scaled, Y_train)

# %%
log_reg.predict(X_train_scaled)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
log_reg.score(X_train_scaled, Y_train)
# Out:
# 0.8849041825492141

# %%
log_reg.score(X_test_scaled, Y_test)
# Out:
# 0.8848160157902157

# %%
log_reg = LogisticRegression(random_state=0,
                            fit_intercept=True
                            ).fit(X_train_scaled, Y_train)

# %%
log_reg.score(X_train_scaled, Y_train)
# Out:
# 0.8849041825492141

# %%
log_reg.score(X_test_scaled, Y_test)
# Out:
# 0.8848160157902157

# %%
Y_pred = log_reg.predict(X_test_scaled)

# %%
Y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

#Confusion Matrix

CM = confusion_matrix(Y_test,Y_pred)
print('Confusion Matrix : ', CM)
# Out:
# Confusion Matrix :  [[56283   127]
#  [ 7226   201]]

# %%
#Accuracy score
Accuracy = accuracy_score(Y_test, Y_pred)
print('Accuracy Score : ', Accuracy)
# Out:
# Accuracy :  0.8848160157902157

# %%
#Precision Score
Precision = precision_score(Y_test, Y_pred)
print('Precision Score : ', Precision)
# Out:
# Precision Score :  0.6128048780487805

# %%
#Recall Score

Recall = recall_score(Y_test,Y_pred)
print('Recall Score : ', Recall)
# Out:
# Recall Score :  0.027063417261343745

# %%
Y_prob = log_reg.predict_proba(X_test_scaled)[:,1]

Y_prob
# Out:
# array([0.02981197, 0.04171076, 0.0913388 , ..., 0.18715174, 0.05986825,
#        0.11500584])

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(Y_test,Y_prob)

# %%
plt.plot(fpr, tpr, label="ROC Curve")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.legend()
plt.show()

# %%
AUC = roc_auc_score(Y_test, Y_prob)

print('AUC Score : ',AUC)
# Out:
# AUC Score :  0.7456057371224216
